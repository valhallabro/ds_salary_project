# %%
import Glassdoor_scrape as gs
import pandas as pd
path = "C:/Users/USER/Documents/ds_salary_proj/chromedriver"

# %%
df = gs.get_jobs('data scientist', 15, False, path, 15)
# Out:
# Progress: 0/15
# Progress: 1/15
# Progress: 2/15
# Progress: 3/15
# Progress: 4/15
# Progress: 5/15
# Progress: 6/15
# Progress: 7/15
# Progress: 8/15
# Progress: 9/15
# Progress: 10/15
# Progress: 11/15
# Progress: 12/15
# Progress: 13/15
# Progress: 14/15
# Progress: 15/15

# %%
df
# Out:
#                           Job Title  Salary Estimate  \
# 0                    Data Scientist               -1
# 1     Business Intelligence Analyst               -1
# 2                    Data Scientist               -1
# 3      Senior Clinical Data Analyst               -1
# 4                    Data Scientist               -1
# 5                    Data Scientist               -1
# 6                    Data Scientist               -1
# 7                    Data Scientist               -1
# 8                    Data Scientist               -1
# 9   Big Data & Analytics Consultant               -1
# 10                   Data Scientist               -1
# 11                   Data Scientist               -1
# 12                   Data Scientist               -1
# 13                   Data Scientist               -1
# 14                   Data Scientist               -1
#
#                                       Job Description Rating  \
# ...
